# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardova28/2025_UTEC_Programacion101/blob/main/IA_fund_TrabajoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports the LSTM model and library
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import InputLayer, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_excel("Inputs01.xlsx")

# %%
df.head(8)
# Out:
#         Time  PPT_RCP45  Tmin_RCP26   Flow
# 0 1950-01-01       3.19       -9.35   58.0
# 1 1950-01-02       2.66       -9.61   61.2
# 2 1950-01-03       2.53      -10.04   63.4
# 3 1950-01-04       3.73      -10.75   49.0
# 4 1950-01-05       3.12       -9.62   60.9
# 5 1950-01-06       1.83       -8.35   86.1
# 6 1950-01-07       2.78       -8.67  129.0
# 7 1950-01-08       3.32       -8.29  120.0

# %%
df.columns = df.columns.str.strip()
df.index = pd.to_datetime(df['Time'], format='%Y.%m.%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26298 entries, 1950-01-01 to 2021-12-31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time        26298 non-null  datetime64[ns]
#  1   PPT_RCP45   26298 non-null  float64
#  2   Tmin_RCP26  26298 non-null  float64
#  3   Flow        26298 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 1.0 MB

# %%
# Strip spaces from all column names
df.columns = df.columns.str.strip()

# Now you can use 'Date' without the space
df['Time'] = pd.to_datetime(df['Time'], format='%d/%m/%Y', errors='coerce')
df.set_index('Time', inplace=True)
df.head()
# Out:
#             PPT_RCP45  Tmin_RCP26  Flow
# Time
# 1950-01-01       3.19       -9.35  58.0
# 1950-01-02       2.66       -9.61  61.2
# 1950-01-03       2.53      -10.04  63.4
# 1950-01-04       3.73      -10.75  49.0
# 1950-01-05       3.12       -9.62  60.9

# %%
print(df.columns)
# Out:
# Index(['PPT_RCP45', 'Tmin_RCP26', 'Flow'], dtype='object')

# %%
flow = df['Flow']
flow.plot()
